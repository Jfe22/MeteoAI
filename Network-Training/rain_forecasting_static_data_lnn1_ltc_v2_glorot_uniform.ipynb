# %% [markdown]
# # Rain Forecasting Using Liquid Neural Networks (Static Data)
# José Ferreira and Rúben Antunes

# %% [markdown]
# ## Import required libraries

# %%
# Library for operating system functionalities
import os
# Library for numerical operations
import numpy as np
# Library for data manipulation and analysis
import pandas as pd
# Library for interactive data visualization
import matplotlib.pyplot as plt
# Library for image processing and manipulation
from PIL import Image
# Library for reading and writing Excel files
from openpyxl import load_workbook
# Library for reading and writing JSON files
import json
# Library for date and time operations
from datetime import datetime, timedelta
# Library for data splitting
from sklearn.model_selection import StratifiedKFold
# Library for confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Libraries for Deep Learning models
import tensorflow as tf
from tensorflow import keras
# Library for Liquid Neural Networks
from ncps.keras import LTC
from ncps.wirings import AutoNCP
# Auxiliary functions module
import auxiliary_functions as aux_func

# %% [markdown]
# ## Set Constants and Hyperparameters

# %%
# Constants
DATASET_PATH = 'datasets/precipitation_dataset/'
DATASET_VALUES_PATH = DATASET_PATH + 'values/'
DATASET_IMAGES_PATH = DATASET_PATH + 'images/'
PRECIPITATION_CLASSES = ['Sem Chuva', 'Chuva Fraca', 'Chuva Moderada', 'Chuva Forte']
STATIONS = {
    1200554: 'Faro',
    1200558: 'Evora',
    1200562: 'Beja',
    1200570: 'Castelo Branco',
    1200571: 'Portalegre',
    1200575: 'Braganca',
    1210683: 'Guarda',
    1210702: 'Aveiro',
    1210707: 'Coimbra',
    1210718: 'Leiria',
    1210734: 'Santarem',
    1210770: 'Setubal',
    1240566: 'Vila Real',
    1240610: 'Viana do Castelo',
    1240675: 'Viseu',
    1240903: 'Porto',
    6212124: 'Braga',
    7240919: 'Lisboa'
}
IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS = 100, 100, 4 # Image = 100x100 RGBA
TIME_DIFFERENCE = 1 # Time difference between the image and the precipitation value in hours
SAMPLE_LIMIT = 140 # Limit of samples for each precipitation category (None = no limit)
IMAGE_REPLACEMENT_METHOD = None # Method to be used when an image doesn't exist (None = no replacement)

# Hyperparameters
REPRODUCIBILITY_SEED = 7 # Seed for reproducibility (None = no reproducibility)
LOAD_BEST_WEIGHTS = False # Don't load best weights when comparing weight initialization methods
WEIGHT_INITIALIZATION_METHOD = 'glorot_uniform' # Method to initialize weights (default = glorot_uniform)
EPOCHS = 100 # Number of training epochs
FOLDS = 5 # Number of cross-validation folds
BATCH_SIZE = 8 # Batch size
HIDDEN_LAYERS = 1 # Number of hidden layers
HIDDEN_NEURONS = 64 # Number of neurons in each hidden layer

# %% [markdown]
# ## Data Treatment

# %%
# Initialize numpy and tensorflow seeds for reproducible results
np.random.seed(REPRODUCIBILITY_SEED)
tf.random.set_seed(REPRODUCIBILITY_SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# Initialize counter for samples of each precipitation category
counter_dictionary = {key: 0 for key in range(len(PRECIPITATION_CLASSES))}

# Initialize arrays to store precipitation values and images
precipitation_array = np.empty(0, dtype=int)
images_array = np.empty((0, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))

# Shuffle stations IDs to avoid bias
stations_ids = list(STATIONS.keys())
np.random.shuffle(stations_ids)

# Iterate over the stations
for station_id in stations_ids:
    # Load the station JSON data
    station_json = DATASET_VALUES_PATH + str(station_id) + '.json'
    with open(station_json) as f:
        json_data = json.load(f)

    # Iterate over the precipitation values
    for date, hours in json_data.items():
        for hour in hours:
            precipitation_value = json_data[date][hour]

            # If there's a sample limit and the current precipitation value has already reached the limit, skip the current iteration
            if SAMPLE_LIMIT is not None and counter_dictionary[precipitation_value] == SAMPLE_LIMIT:
                continue

            # Get the image path
            precipitation_datetime_string = date + ' ' + hour
            precipitation_datetime = datetime.strptime(precipitation_datetime_string, "%Y-%m-%d %H:%M")
            image_datetime = precipitation_datetime - timedelta(hours=TIME_DIFFERENCE)
            image_date_string = image_datetime.strftime("%Y-%m-%d")
            image_datetime_string = image_datetime.strftime("%Y-%m-%dT%H%M")
            folder_path = DATASET_IMAGES_PATH + str(station_id)
            image_path = folder_path + '/' + image_date_string + '/' + image_datetime_string + '.png'

            # If the image exist, open it
            if os.path.exists(image_path):
                image = Image.open(image_path)
            # If the image doesn't exist, generate a replacement image
            else:
                image = aux_func.generate_replacement_image(folder_path, image_datetime, IMAGE_REPLACEMENT_METHOD)
                # If there's no replacement image, break the current cycle
                if image is None:
                    break

            # Resize the image
            resized_image = image.resize((IMAGE_WIDTH, IMAGE_HEIGHT))

            # Convert the image to an array
            image_array = np.array(resized_image)

            # Normalize pixel values to be between 0 and 1
            image_array = image_array / 255

            # Close the image
            image.close()

            # Add the precipitation value to the precipitation array
            precipitation_array = np.append(precipitation_array, precipitation_value)

            # Add the image to the images array
            images_array = np.append(images_array, [image_array], axis=0)

            # Increment the counter for the current precipitation value
            counter_dictionary[precipitation_value] += 1

# Visualize dataset sample
print('Dataset sample:')
aux_func.show_dataset_sample_static(images_array, precipitation_array, PRECIPITATION_CLASSES)

print('Number of samples of each class:')
for key, value in aux_func.count_occurrences_of_each_value(precipitation_array).items():
    print(f'{key}: {value}')
# Out:
# Dataset sample:
# Number of samples of each class:
# 0: 140
# 1: 140
# 2: 140
# 3: 140

# %% [markdown]
# ## Model Initialization

# %%
# Reset all state generated by keras
keras.backend.clear_session()

# Initialize the model to allow weight initialization before actual training
base_model = keras.Sequential([
    keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)),
    keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', strides=1, padding='same', data_format='channels_last'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', strides=1, padding='same', data_format='channels_last'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
    keras.layers.Dropout(0.35),
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', strides=1, padding='same', data_format='channels_last'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same', activation='relu', data_format='channels_last'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid' ),
    keras.layers.Dropout(0.0035),
    keras.layers.Flatten(name='flatten')
])

# Print model summary
base_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\antun\Desktop\UNI\PI\Experiments\Network-Training-Experiments\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 100, 32)   │         1,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 100, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 100, 100, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 100, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 50, 50, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 50, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 50, 50, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 50, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 40000)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,624 (260.25 KB)
#  Trainable params: 66,240 (258.75 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# ## Weight Initialization

# %%
# Create 3 initializers that will train the model
print('Weight initialization - Start')
initializer1, initializer2, initializer3 = aux_func.get_weight_initializer(base_model, HIDDEN_NEURONS, IMAGE_HEIGHT * IMAGE_WIDTH * IMAGE_CHANNELS, len(PRECIPITATION_CLASSES), images_array, precipitation_array, WEIGHT_INITIALIZATION_METHOD, REPRODUCIBILITY_SEED)
print('Weight initialization - End')
# Out:
# Weight initialization - Start
# Method GlorotUniform
# Weight initialization - End

# %% [markdown]
# ## Model Training (CNN+LTC)

# %%
# Initialize xls writer to store results
xlsFileName = 'results/LNN1_Train_Static_Data_Method_' + str(WEIGHT_INITIALIZATION_METHOD) + '_HL' + str(HIDDEN_LAYERS) + '_N' + str(HIDDEN_NEURONS) + '_Folds' + str(FOLDS) + '_Epochs' + str(EPOCHS) + '_' + datetime.now().strftime("%Y_%m_%d_%H%M%S") + '.xlsx'
writer = pd.ExcelWriter(xlsFileName, engine='openpyxl')

# Initialize arrays to store results
runtimes = []
accuracies = []
val_accuracies = []
losses = []
val_losses = []
precisions = []
val_precisions = []
recalls = []
val_recalls = []

try:
    # Stratified k-fold cross validation
    skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=REPRODUCIBILITY_SEED)
    for fold, (train_idx, val_idx) in enumerate(skf.split(images_array, precipitation_array)):
        print(f'\nFold {fold+1}/{FOLDS}\n')

        # Split the data
        train_images, val_images = images_array[train_idx], images_array[val_idx]
        train_labels, val_labels = precipitation_array[train_idx], precipitation_array[val_idx]

        # One-hot encode the labels
        train_labels_one_hot = keras.utils.to_categorical(train_labels, num_classes=len(PRECIPITATION_CLASSES))
        val_labels_one_hot = keras.utils.to_categorical(val_labels, num_classes=len(PRECIPITATION_CLASSES))

        # Reset all state generated by keras
        keras.backend.clear_session()

        # Rebuild model
        lnn_model = keras.Sequential([
            keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)),
            keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', strides=1, padding='same', data_format='channels_last'),
            keras.layers.BatchNormalization(),
            keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', strides=1, padding='same', data_format='channels_last'),
            keras.layers.BatchNormalization(),
            keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
            keras.layers.Dropout(0.35),
            keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', strides=1, padding='same', data_format='channels_last'),
            keras.layers.BatchNormalization(),
            keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='same', activation='relu', data_format='channels_last'),
            keras.layers.BatchNormalization(),
            keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid' ),
            keras.layers.Dropout(0.0035),
            keras.layers.Flatten(name='flatten')
        ])
        lnn_model.add(keras.layers.Dense(HIDDEN_NEURONS, activation='relu', kernel_initializer=initializer1))
        # Add hidden layers
        for hidden_layer in range(HIDDEN_LAYERS):
            lnn_model.add(keras.layers.Dense(HIDDEN_NEURONS, activation='relu', kernel_initializer=initializer2))
        lnn_model.add(keras.layers.BatchNormalization())
        lnn_model.add(keras.layers.Reshape((1, HIDDEN_NEURONS), name='reshape'))
        lnn_model.add(LTC(AutoNCP(HIDDEN_NEURONS, output_size=len(PRECIPITATION_CLASSES))))
        lnn_model.add(keras.layers.Dense(len(PRECIPITATION_CLASSES), activation='softmax', kernel_initializer=initializer3))

        # Compile model
        lnn_model.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy', 'precision', 'recall', 'f1_score'])

        # Callback to record epoch computation time
        time_callback = aux_func.TimeHistory()

        # Callback to save model weights
        model_checkpoint = keras.callbacks.ModelCheckpoint(filepath='model_weights/lnn1_static_data_time_difference_' + str(TIME_DIFFERENCE) + '.weights.h5', monitor='val_accuracy', save_best_only=True, verbose=1, mode='max', save_weights_only=True)

        # Load best weights
        if LOAD_BEST_WEIGHTS:
            weights_path = 'model_weights/lnn1_static_data_time_difference_' + str(TIME_DIFFERENCE) + '.weights.h5'
            try:
                lnn_model.load_weights(weights_path)
                print('Weights loaded')
            except:
                print('Weights not loaded')

        # Data augmentation
        datagen = keras.preprocessing.image.ImageDataGenerator(
            rotation_range=5,
            width_shift_range=0.02,
            height_shift_range=0.02,
            shear_range=0.02,
            zoom_range=0,
            fill_mode='nearest'
        )

        # Train model
        history = lnn_model.fit(datagen.flow(train_images, train_labels_one_hot, batch_size=BATCH_SIZE), epochs=EPOCHS, validation_data=(val_images, val_labels_one_hot), callbacks=[model_checkpoint, time_callback])

        # Show fold results
        epochs_range = range(1, EPOCHS + 1)
        fig, ax1 = plt.subplots()
        ax1.set_title('Training and Validation Results')
        ax1.set_xlabel('Epochs')
        ax1.set_ylabel('Accuracy')
        ax1.set_ylim(0, 1)
        ax1.plot(epochs_range, history.history['accuracy'], color='blue', linestyle='-', label='Training Accuracy')
        ax1.plot(epochs_range, history.history['val_accuracy'], color='red', linestyle='-', label='Validation Accuracy')
        ax1.legend(loc='upper left')
        ax2 = ax1.twinx()
        ax2.set_ylabel('Loss')
        ax2.plot(epochs_range, history.history['loss'], color='blue', linestyle=':', label='Training Loss')
        ax2.plot(epochs_range, history.history['val_loss'], color='red', linestyle=':', label='Validation Loss')
        ax2.legend(loc='upper right')
        fig.tight_layout()
        plt.show()

        # Calculate confusion matrix
        predictions = lnn_model.predict(val_images)
        predicted_labels = np.argmax(predictions, axis=1)
        true_labels = np.argmax(val_labels_one_hot, axis=1)
        cm = confusion_matrix(true_labels, predicted_labels)

        # Show confusion matrix
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=PRECIPITATION_CLASSES)
        disp.plot(cmap='Blues')
        plt.title('Confusion Matrix')
        plt.show()

        # Store best results
        runtimes.append(np.mean(time_callback.times))
        accuracies.append(max(history.history['accuracy']))
        val_accuracies.append(max(history.history['val_accuracy']))
        losses.append(min(history.history['loss']))
        val_losses.append(min(history.history['val_loss']))
        precisions.append(max(history.history['precision']))
        val_precisions.append(max(history.history['val_precision']))
        recalls.append(max(history.history['recall']))
        val_recalls.append(max(history.history['val_recall']))

        # Save fold results
        fold_results = {
            'epoch' : epochs_range,
            'runtime' : np.round(time_callback.times, 4),
            'accuracy': np.round(history.history['accuracy'], 4),
            'val_accuracy': np.round(history.history['val_accuracy'], 4),
            'loss' : np.round(history.history['loss'], 4),
            'val_loss' : np.round(history.history['val_loss'], 4),
            'precision': np.round(history.history['precision'], 4),
            'val_precision': np.round(history.history['val_precision'], 4),
            'recall': np.round(history.history['recall'], 4),
            'val_recall': np.round(history.history['val_recall'], 4)
        }
        df = pd.DataFrame(fold_results)
        sheet_name = f'Fold_{fold+1}_Results'
        df.to_excel(writer, sheet_name=sheet_name, index=False)

    # Calculate and save average results
    final_results = {
        'model' : 'LNN',
        'time_difference' : TIME_DIFFERENCE,
        'sample_limit' : SAMPLE_LIMIT,
        'loaded_best_weights': str(LOAD_BEST_WEIGHTS),
        'weigh_initialization_method' : str(WEIGHT_INITIALIZATION_METHOD),
        'hidden_layers' : HIDDEN_LAYERS,
        'hidden_neurons' : HIDDEN_NEURONS,
        'epochs' : EPOCHS,
        'folds' : FOLDS,
        'batch_size' : BATCH_SIZE,
        'avg_epoch_runtime' : np.round(np.mean(runtimes), 4),
        'accuracy' : np.round(np.mean(accuracies), 4),
        'val_accuracy' : np.round(np.mean(val_accuracies), 4),
        'loss' : np.round(np.mean(losses), 4),
        'val_loss' : np.round(np.mean(val_losses), 4),
        'precision' : np.round(np.mean(precisions), 4),
        'val_precision' : np.round(np.mean(val_precisions), 4),
        'recall' : np.round(np.mean(recalls), 4),
        'val_recall' : np.round(np.mean(val_recalls), 4)
    }
    df = pd.DataFrame(final_results, index=[0])
    sheet_name = 'Folds_Average_Results'
    df.to_excel(writer, sheet_name=sheet_name, index=False)

    # Show final results
    print('\n --- Training completed --- \n')
    for key, value in final_results.items():
        print(f'{key}: {value}')

    # Show model summary
    lnn_model.summary()
except KeyboardInterrupt:
    print('\n --- Training interrupted by user --- ')
finally:
    #Close the Writer
    writer.close()

    # Move last sheet to first position
    wb = load_workbook(xlsFileName)
    last_sheet_name = wb.sheetnames[-1]
    sheet_to_move = wb[last_sheet_name]
    wb.remove(sheet_to_move)
    wb._sheets = [sheet_to_move] + wb._sheets
    wb.save(xlsFileName)
# Out:
# Fold 1/5
#
# Epoch 1/100
# C:\Users\antun\Desktop\UNI\PI\Experiments\Network-Training-Experiments\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.4051 - f1_score: 0.2633 - loss: 1.3429 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: val_accuracy improved from -inf to 0.25000, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 32s 278ms/step - accuracy: 0.4055 - f1_score: 0.2642 - loss: 1.3428 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2500 - val_f1_score: 0.1000 - val_loss: 1.3812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5394 - f1_score: 0.4337 - loss: 1.2730 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_accuracy improved from 0.25000 to 0.27679, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 255ms/step - accuracy: 0.5393 - f1_score: 0.4344 - loss: 1.2728 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2768 - val_f1_score: 0.1477 - val_loss: 1.3776 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6215 - f1_score: 0.6066 - loss: 1.2030 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: val_accuracy improved from 0.27679 to 0.42857, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 272ms/step - accuracy: 0.6219 - f1_score: 0.6070 - loss: 1.2028 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.4286 - val_f1_score: 0.3397 - val_loss: 1.3230 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.7196 - f1_score: 0.7099 - loss: 1.1266 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: val_accuracy improved from 0.42857 to 0.56250, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 264ms/step - accuracy: 0.7189 - f1_score: 0.7092 - loss: 1.1266 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.5625 - val_f1_score: 0.4873 - val_loss: 1.2869 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.6798 - f1_score: 0.6680 - loss: 1.0801 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: val_accuracy did not improve from 0.56250
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 258ms/step - accuracy: 0.6797 - f1_score: 0.6679 - loss: 1.0798 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.5357 - val_f1_score: 0.4812 - val_loss: 1.2410 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7551 - f1_score: 0.7447 - loss: 0.9868 - precision: 0.6858 - recall: 0.0732
# Epoch 6: val_accuracy did not improve from 0.56250
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 258ms/step - accuracy: 0.7549 - f1_score: 0.7446 - loss: 0.9866 - precision: 0.6897 - recall: 0.0745 - val_accuracy: 0.5446 - val_f1_score: 0.4594 - val_loss: 1.1928 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7354 - f1_score: 0.7201 - loss: 0.9248 - precision: 0.9039 - recall: 0.2423
# Epoch 7: val_accuracy did not improve from 0.56250
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 0.7359 - f1_score: 0.7206 - loss: 0.9244 - precision: 0.9043 - recall: 0.2431 - val_accuracy: 0.5536 - val_f1_score: 0.5225 - val_loss: 1.1304 - val_precision: 0.8462 - val_recall: 0.1964
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8078 - f1_score: 0.8011 - loss: 0.8283 - precision: 0.9351 - recall: 0.3965
# Epoch 8: val_accuracy improved from 0.56250 to 0.61607, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 259ms/step - accuracy: 0.8075 - f1_score: 0.8010 - loss: 0.8282 - precision: 0.9352 - recall: 0.3965 - val_accuracy: 0.6161 - val_f1_score: 0.5761 - val_loss: 1.0773 - val_precision: 1.0000 - val_recall: 0.0893
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.8439 - f1_score: 0.8349 - loss: 0.7352 - precision: 0.9313 - recall: 0.4633
# Epoch 9: val_accuracy did not improve from 0.61607
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 258ms/step - accuracy: 0.8435 - f1_score: 0.8345 - loss: 0.7355 - precision: 0.9306 - recall: 0.4637 - val_accuracy: 0.6161 - val_f1_score: 0.5815 - val_loss: 1.0100 - val_precision: 0.8529 - val_recall: 0.2589
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.8418 - f1_score: 0.8382 - loss: 0.7234 - precision: 0.9240 - recall: 0.5320
# Epoch 10: val_accuracy did not improve from 0.61607
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 259ms/step - accuracy: 0.8417 - f1_score: 0.8381 - loss: 0.7231 - precision: 0.9241 - recall: 0.5326 - val_accuracy: 0.5714 - val_f1_score: 0.5156 - val_loss: 1.0169 - val_precision: 0.8200 - val_recall: 0.3661
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8634 - f1_score: 0.8543 - loss: 0.6675 - precision: 0.9123 - recall: 0.6301
# Epoch 11: val_accuracy improved from 0.61607 to 0.64286, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 0
- precision: 0.9967 - recall: 0.9967 - val_accuracy: 0.6518 - val_f1_score: 0.6452 - val_loss: 1.5617 - val_precision: 0.6518 - val_recall: 0.6518
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9931 - f1_score: 0.9931 - loss: 0.0296 - precision: 0.9931 - recall: 0.9922
# Epoch 94: val_accuracy did not improve from 0.69643
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 266ms/step - accuracy: 0.9930 - f1_score: 0.9930 - loss: 0.0299 - precision: 0.9930 - recall: 0.9921 - val_accuracy: 0.6696 - val_f1_score: 0.6682 - val_loss: 1.6198 - val_precision: 0.6757 - val_recall: 0.6696
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9900 - f1_score: 0.9856 - loss: 0.0484 - precision: 0.9900 - recall: 0.9900
# Epoch 95: val_accuracy improved from 0.69643 to 0.70536, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 260ms/step - accuracy: 0.9900 - f1_score: 0.9857 - loss: 0.0483 - precision: 0.9900 - recall: 0.9900 - val_accuracy: 0.7054 - val_f1_score: 0.7019 - val_loss: 1.5340 - val_precision: 0.7054 - val_recall: 0.7054
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9912 - f1_score: 0.9871 - loss: 0.0202 - precision: 0.9912 - recall: 0.9912
# Epoch 96: val_accuracy did not improve from 0.70536
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - accuracy: 0.9913 - f1_score: 0.9872 - loss: 0.0202 - precision: 0.9913 - recall: 0.9913 - val_accuracy: 0.6696 - val_f1_score: 0.6685 - val_loss: 1.5595 - val_precision: 0.6696 - val_recall: 0.6696
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9937 - f1_score: 0.9937 - loss: 0.0263 - precision: 0.9937 - recall: 0.9937
# Epoch 97: val_accuracy did not improve from 0.70536
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 252ms/step - accuracy: 0.9936 - f1_score: 0.9936 - loss: 0.0266 - precision: 0.9936 - recall: 0.9936 - val_accuracy: 0.6875 - val_f1_score: 0.6844 - val_loss: 1.5546 - val_precision: 0.6847 - val_recall: 0.6786
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9956 - f1_score: 0.9912 - loss: 0.0233 - precision: 0.9956 - recall: 0.9956
# Epoch 98: val_accuracy did not improve from 0.70536
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 249ms/step - accuracy: 0.9955 - f1_score: 0.9912 - loss: 0.0234 - precision: 0.9955 - recall: 0.9955 - val_accuracy: 0.6786 - val_f1_score: 0.6777 - val_loss: 1.5456 - val_precision: 0.6786 - val_recall: 0.6786
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9960 - f1_score: 0.9960 - loss: 0.0283 - precision: 0.9960 - recall: 0.9960
# Epoch 99: val_accuracy did not improve from 0.70536
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 260ms/step - accuracy: 0.9959 - f1_score: 0.9959 - loss: 0.0284 - precision: 0.9959 - recall: 0.9959 - val_accuracy: 0.6696 - val_f1_score: 0.6639 - val_loss: 1.5517 - val_precision: 0.6696 - val_recall: 0.6696
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9814 - f1_score: 0.9802 - loss: 0.0606 - precision: 0.9814 - recall: 0.9814
# Epoch 100: val_accuracy did not improve from 0.70536
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - accuracy: 0.9815 - f1_score: 0.9803 - loss: 0.0604 - precision: 0.9815 - recall: 0.9815 - val_accuracy: 0.6875 - val_f1_score: 0.6774 - val_loss: 1.5459 - val_precision: 0.6875 - val_recall: 0.6875
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step
# Fold 2/5
#
# Epoch 1/100
# C:\Users\antun\Desktop\UNI\PI\Experiments\Network-Training-Experiments\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.4202 - f1_score: 0.3398 - loss: 1.3498 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: val_accuracy improved from -inf to 0.37500, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 26s 271ms/step - accuracy: 0.4210 - f1_score: 0.3407 - loss: 1.3494 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3750 - val_f1_score: 0.2444 - val_loss: 1.3875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.5356 - f1_score: 0.4668 - loss: 1.2810 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_accuracy improved from 0.37500 to 0.39286, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - accuracy: 0.5359 - f1_score: 0.4673 - loss: 1.2808 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3929 - val_f1_score: 0.2632 - val_loss: 1.3951 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.5711 - f1_score: 0.5126 - loss: 1.2367 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: val_accuracy did not improve from 0.39286
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 0.5714 - f1_score: 0.5130 - loss: 1.2365 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3571 - val_f1_score: 0.2672 - val_loss: 1.3446 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6263 - f1_score: 0.5800 - loss: 1.1732 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4: val_accuracy improved from 0.39286 to 0.44643, saving model to model_weights/lnn1_static_data_time_difference_1.weights.h5
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 259ms/step - accuracy: 0.6263 - f1_score: 0.5801 - loss: 1.1731 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.4464 - val_f1_score: 0.3340 - val_loss: 1.2829 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6544 - f1_score: 0.6224 - loss: 1.1102 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: val_accuracy did not improve from 0.44643
# ...
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9814 - f1_score: 0.9781 - loss: 0.0459 - precision: 0.9814 - recall: 0.9804
# Epoch 74: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 264ms/step - accuracy: 0.9815 - f1_score: 0.9782 - loss: 0.0459 - precision: 0.9815 - recall: 0.9805 - val_accuracy: 0.6518 - val_f1_score: 0.6571 - val_loss: 1.2866 - val_precision: 0.6545 - val_recall: 0.6429
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0322 - precision: 0.9998 - recall: 0.9998
# Epoch 75: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 263ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0325 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.6786 - val_f1_score: 0.6795 - val_loss: 1.2829 - val_precision: 0.6757 - val_recall: 0.6696
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9780 - f1_score: 0.9736 - loss: 0.0621 - precision: 0.9790 - recall: 0.9780
# Epoch 76: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 260ms/step - accuracy: 0.9780 - f1_score: 0.9736 - loss: 0.0623 - precision: 0.9790 - recall: 0.9780 - val_accuracy: 0.6339 - val_f1_score: 0.6350 - val_loss: 1.4251 - val_precision: 0.6389 - val_recall: 0.6161
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9933 - f1_score: 0.9934 - loss: 0.0577 - precision: 0.9940 - recall: 0.9933
# Epoch 77: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 258ms/step - accuracy: 0.9932 - f1_score: 0.9933 - loss: 0.0579 - precision: 0.9939 - recall: 0.9932 - val_accuracy: 0.6607 - val_f1_score: 0.6618 - val_loss: 1.3678 - val_precision: 0.6636 - val_recall: 0.6518
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9931 - f1_score: 0.9930 - loss: 0.0367 - precision: 0.9931 - recall: 0.9931
# Epoch 78: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 258ms/step - accuracy: 0.9930 - f1_score: 0.9929 - loss: 0.0369 - precision: 0.9930 - recall: 0.9930 - val_accuracy: 0.6607 - val_f1_score: 0.6656 - val_loss: 1.3602 - val_precision: 0.6667 - val_recall: 0.6607
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9907 - f1_score: 0.9906 - loss: 0.0422 - precision: 0.9907 - recall: 0.9882
# Epoch 79: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 260ms/step - accuracy: 0.9907 - f1_score: 0.9906 - loss: 0.0422 - precision: 0.9907 - recall: 0.9882 - val_accuracy: 0.6518 - val_f1_score: 0.6521 - val_loss: 1.2679 - val_precision: 0.6577 - val_recall: 0.6518
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9910 - f1_score: 0.9909 - loss: 0.0336 - precision: 0.9910 - recall: 0.9910
# Epoch 80: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 258ms/step - accuracy: 0.9908 - f1_score: 0.9907 - loss: 0.0342 - precision: 0.9908 - recall: 0.9908 - val_accuracy: 0.6875 - val_f1_score: 0.6852 - val_loss: 1.3233 - val_precision: 0.6875 - val_recall: 0.6875
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9903 - f1_score: 0.9904 - loss: 0.0284 - precision: 0.9903 - recall: 0.9903
# Epoch 81: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 261ms/step - accuracy: 0.9903 - f1_score: 0.9904 - loss: 0.0285 - precision: 0.9903 - recall: 0.9903 - val_accuracy: 0.6607 - val_f1_score: 0.6595 - val_loss: 1.3721 - val_precision: 0.6667 - val_recall: 0.6607
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9737 - f1_score: 0.9722 - loss: 0.0753 - precision: 0.9737 - recall: 0.9737
# Epoch 82: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 261ms/step - accuracy: 0.9738 - f1_score: 0.9723 - loss: 0.0752 - precision: 0.9738 - recall: 0.9738 - val_accuracy: 0.6518 - val_f1_score: 0.6515 - val_loss: 1.3883 - val_precision: 0.6486 - val_recall: 0.6429
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9711 - f1_score: 0.9702 - loss: 0.0894 - precision: 0.9710 - recall: 0.9701
# Epoch 83: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 274ms/step - accuracy: 0.
val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 256ms/step - accuracy: 0.9922 - f1_score: 0.9918 - loss: 0.0381 - precision: 0.9922 - recall: 0.9922 - val_accuracy: 0.6607 - val_f1_score: 0.6673 - val_loss: 1.4499 - val_precision: 0.6636 - val_recall: 0.6518
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9969 - f1_score: 0.9970 - loss: 0.0295 - precision: 0.9969 - recall: 0.9941
# Epoch 94: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 273ms/step - accuracy: 0.9969 - f1_score: 0.9970 - loss: 0.0297 - precision: 0.9969 - recall: 0.9940 - val_accuracy: 0.6607 - val_f1_score: 0.6692 - val_loss: 1.5619 - val_precision: 0.6607 - val_recall: 0.6607
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9842 - f1_score: 0.9798 - loss: 0.0686 - precision: 0.9842 - recall: 0.9842
# Epoch 95: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 0.9841 - f1_score: 0.9798 - loss: 0.0686 - precision: 0.9841 - recall: 0.9841 - val_accuracy: 0.6339 - val_f1_score: 0.6394 - val_loss: 1.4495 - val_precision: 0.6339 - val_recall: 0.6339
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9911 - f1_score: 0.9909 - loss: 0.0385 - precision: 0.9911 - recall: 0.9902
# Epoch 96: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 0.9910 - f1_score: 0.9908 - loss: 0.0390 - precision: 0.9910 - recall: 0.9901 - val_accuracy: 0.6518 - val_f1_score: 0.6555 - val_loss: 1.5121 - val_precision: 0.6486 - val_recall: 0.6429
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9885 - f1_score: 0.9842 - loss: 0.0497 - precision: 0.9926 - recall: 0.9885
# Epoch 97: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 261ms/step - accuracy: 0.9885 - f1_score: 0.9843 - loss: 0.0495 - precision: 0.9927 - recall: 0.9885 - val_accuracy: 0.6696 - val_f1_score: 0.6730 - val_loss: 1.4966 - val_precision: 0.6852 - val_recall: 0.6607
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9887 - f1_score: 0.9888 - loss: 0.0557 - precision: 0.9897 - recall: 0.9887
# Epoch 98: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 256ms/step - accuracy: 0.9887 - f1_score: 0.9888 - loss: 0.0555 - precision: 0.9897 - recall: 0.9887 - val_accuracy: 0.6339 - val_f1_score: 0.6461 - val_loss: 1.5779 - val_precision: 0.6339 - val_recall: 0.6339
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9772 - f1_score: 0.9781 - loss: 0.0457 - precision: 0.9874 - recall: 0.9757
# Epoch 99: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9774 - f1_score: 0.9782 - loss: 0.0455 - precision: 0.9874 - recall: 0.9759 - val_accuracy: 0.6339 - val_f1_score: 0.6336 - val_loss: 1.6785 - val_precision: 0.6339 - val_recall: 0.6339
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9981 - f1_score: 0.9936 - loss: 0.0221 - precision: 0.9981 - recall: 0.9981
# Epoch 100: val_accuracy did not improve from 0.72321
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 0.9980 - f1_score: 0.9936 - loss: 0.0223 - precision: 0.9980 - recall: 0.9980 - val_accuracy: 0.6518 - val_f1_score: 0.6517 - val_loss: 1.6300 - val_precision: 0.6518 - val_recall: 0.6518
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step
#  --- Training completed ---
#
# model: LNN
# time_difference: 1
# sample_limit: 140
# loaded_best_weights: False
# weigh_initialization_method: glorot_uniform
# hidden_layers: 1
# hidden_neurons: 64
# epochs: 100
# folds: 5
# batch_size: 8
# avg_epoch_runtime: 14.612
# accuracy: 0.9973
# val_accuracy: 0.7393
# loss: 0.0225
# val_loss: 0.7331
# precision: 0.9978
# val_precision: 0.9742
# recall: 0.9969
# val_recall: 0.7321
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 100, 32)   │         1,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 100, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 100, 100, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 100, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 50, 50, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 50, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 50, 50, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 50, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 40000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     2,560,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ltc (LTC)                       │ (None, 4)              │        33,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,991,638 (30.49 MB)
#  Trainable params: 2,663,708 (10.16 MB)
#  Non-trainable params: 512 (2.00 KB)
#  Optimizer params: 5,327,418 (20.32 MB)
